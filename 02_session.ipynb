# %% [markdown]
# # Day 02
# ## Importing Data and saving it as a Dataframe

# %%
import pandas as pd

# read the data from the csv file
# data_weather = pd.read_csv("https://raw.githubusercontent.com/opencampus-sh/einfuehrung-in-data-science-und-ml/main/wetter.csv")

# read kiwo.csv from this github repo (https://github.com/opencampus-sh/einfuehrung-in-data-science-und-ml)
# data_kiwo = pd.read_csv("https://raw.githubusercontent.com/opencampus-sh/einfuehrung-in-data-science-und-ml/main/kiwo.csv")

# read umsatzdaten_gekuerzt.csv from this github repo (https://github.com/opencampus-sh/einfuehrung-in-data-science-und-ml)
# data_umsatzdaten_gekuerzt = pd.read_csv("https://raw.githubusercontent.com/opencampus-sh/einfuehrung-in-data-science-und-ml/main/umsatzdaten_gekuerzt.csv")

# %%
# scatterplott, histogram, bar chart (Tests in the session)
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Check the data structure
print(data_weather.head())


# Create a bar chart for Temperatur vs Wochentag
# plt.figure(figsize=(10, 6))
# plt.bar(data_weather['Wochentag'], color='skyblue')
# plt.xlabel('Wochentag')
# plt.ylabel('Temperatur')
# plt.title('Temperatur by Wochentag')
# plt.show()


# scatterplott depicting data_weather (Temperatur & Windgeschwindigkeit) using matplotlib
plt.scatter(data_weather['Temperatur'], data_weather['Windgeschwindigkeit'])
plt.show()


# histogram depicting data_weather using matplotlib
plt.hist(data_weather['Temperatur'], bins=20)
data_weather['Temperatur'].plot.hist(bins=20)
# Out:
#         Datum  Bewoelkung  Temperatur  Windgeschwindigkeit  Wettercode
# 0  2012-01-01         8.0      9.8250                   14        58.0
# 1  2012-01-02         7.0      7.4375                   12         NaN
# 2  2012-01-03         8.0      5.5375                   18        63.0
# 3  2012-01-04         4.0      5.6875                   19        80.0
# 4  2012-01-05         6.0      5.3000                   23        80.0
# <Axes: ylabel='Frequency'>
